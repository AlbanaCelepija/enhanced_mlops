# %%
# !pip install great_expectations

# %%
import great_expectations as gx
import great_expectations.expectations as gxe

# %%
# Create a data context
context = gx.get_context(mode="file")
datasource = context.data_sources.add_pandas_filesystem(name="recruitmentdataset0", base_directory="../data")
data_asset = datasource.add_csv_asset(name="recruitmentdataset-2022")

# %%
# Create a batch request
batch_definition_name = "recruitmentdataset-2022_1"
batch_definition_path = "recruitmentdataset-2022.csv"

batch_definition = data_asset.add_batch_definition_path(
    name=batch_definition_name, path=batch_definition_path
)
# Get the dataframe as a Batch
batch = batch_definition.get_batch()
print(batch.head())
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#        Id  gender  age  ... ind-degree company  decision
# 0  x8011e  female   24  ...        phd       A      True
# 1  x6077a    male   26  ...   bachelor       A     False
# 2  x6006e  female   23  ...     master       A     False
# 3  x2173b    male   24  ...     master       A      True
# 4  x6241a  female   26  ...     master       A      True
#
# [5 rows x 15 columns]

# %%
# Create an Expectation to test
expectation = gxe.ExpectColumnValuesToBeBetween(
    column="ind-university_grade", max_value=80, min_value=60
)
# Test the Expectation
validation_results = batch.validate(expectation)
validation_results
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "batch_id": "recruitmentdataset0-recruitmentdataset-2022",
#       "column": "ind-university_grade",
#       "min_value": 60.0,
#       "max_value": 80.0
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 4000,
#     "unexpected_count": 1300,
#     "unexpected_percent": 32.5,
#     "partial_unexpected_list": [
#       59,
#       55,
#       56,
#       56,
#       58,
#       56,
#       59,
#       51,
#       57,
#       59,
#       57,
#       58,
#       55,
#       52,
#       59,
#       58,
#       57,
#       51,
#       58,
#       57
#     ],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 32.5,
#     "unexpected_percent_nonmissing": 32.5,
#     "partial_unexpected_counts": [
#       {
#         "value": 57,
#         "count": 4
#       },
#       {
#         "value": 58,
#         "count": 4
#       },
#       {
#         "value": 59,
#         "count": 4
#       },
#       {
#         "value": 56,
#         "count": 3
#       },
#       {
#         "value": 51,
#         "count": 2
#       },
#       {
#         "value": 55,
#         "count": 2
#       },
#       {
#         "value": 52,
#         "count": 1
#       }
#     ],
#     "partial_unexpected_index_list": [
#       4,
#       9,
#       11,
#       13,
#       27,
#       28,
#       34,
#       35,
#       40,
#       48,
#       51,
#       52,
#       53,
#       57,
#       58,
#       59,
#       60,
#       61,
#       64,
#       65
#     ]
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Create an Expectation to test
expectation = gxe.ExpectTableRowCountToEqual(
    value=4000
)
# Test the Expectation
validation_results = batch.validate(expectation)
validation_results
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_table_row_count_to_equal",
#     "kwargs": {
#       "batch_id": "recruitmentdataset0-recruitmentdataset-2022",
#       "value": 4000
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "observed_value": 4000
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
